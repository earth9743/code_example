# %% [markdown]
# Python ver : 3.85
#
# torch : 2.4.1
#
# pandas : 1.3.5
#
# numpy : 1.24.3

# %%
import torch
import torch.nn.functional as F
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score
import pandas as pd
import numpy as np

# %%
# CSV 데이터 로드
df = pd.read_csv("dataset_example.csv")
features = torch.tensor(df.drop(columns=["label"]).values, dtype=torch.float)
labels = torch.tensor(df["label"].values, dtype=torch.long)

# edge_index는 임시 fully connected로 예시 구성 (GCN에서 필요)
def generate_dummy_edges(num_nodes):
    row, col = [], []
    for i in range(num_nodes):
        for j in range(num_nodes):
            if i != j:
                row.append(i)
                col.append(j)
    return torch.tensor([row, col], dtype=torch.long)

edge_index = generate_dummy_edges(features.shape[0])

# %%
# GCN 모델 정의
class GCN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, out_channels)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(x, training=self.training)
        x = self.conv2(x, edge_index)
        return x

# %%
# 전체 데이터 객체 생성
data = Data(x=features, edge_index=edge_index, y=labels)

# 50회 반복 (5-fold × 10회)
total_aucs = []
num_iterations = 0

for repeat in range(10):
    print(f"\n Repeat {repeat+1}/10")
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=repeat) # 5개의 fold로 분할 (매번 1개는 test용)
    splits = list(skf.split(np.zeros(len(labels)), labels)) # 클래스 비율 유지한 채로 (train+val, test) 인덱스 쌍 생성

    for fold, (train_val_idx, test_idx) in enumerate(splits):
        print(f"\nFold {fold+1}/5")
        print(f"- Test indices (sample): {test_idx[:5].tolist()} ... 총 {len(test_idx)}개")
        print(f"- Train+Val indices (sample): {train_val_idx[:5].tolist()} ... 총 {len(train_val_idx)}개")

        # train/val 분리 (전체의 80%에서 80% → train / 20% → val)
        train_idx, val_idx = train_test_split(
            train_val_idx,
            test_size=0.2,
            stratify=labels[train_val_idx],
            random_state=42
        )

        print(f"  - Train size: {len(train_idx)} ({len(train_idx)/len(labels):.2%})")
        print(f"  - Val size:   {len(val_idx)} ({len(val_idx)/len(labels):.2%})")
        print(f"  - Test size:  {len(test_idx)} ({len(test_idx)/len(labels):.2%})")

        # 마스크 설정
        train_mask = torch.zeros(data.num_nodes, dtype=torch.bool)
        val_mask = torch.zeros(data.num_nodes, dtype=torch.bool)
        test_mask = torch.zeros(data.num_nodes, dtype=torch.bool)

        train_mask[train_idx] = True
        val_mask[val_idx] = True
        test_mask[test_idx] = True

        data.train_mask = train_mask
        data.val_mask = val_mask
        data.test_mask = test_mask

        # 모델 및 옵티마이저 초기화
        model = GCN(in_channels=data.num_features, hidden_channels=32, out_channels=2)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)

        # 10 epoch 학습
        model.train()
        for epoch in range(10):
            optimizer.zero_grad()
            out = model(data)
            loss = F.cross_entropy(out[data.train_mask], data.y[data.train_mask])
            loss.backward()
            optimizer.step()

        # AUC 평가
        model.eval()
        with torch.no_grad():
            logits = model(data)
            probs = F.softmax(logits[data.test_mask], dim=1)[:, 1].cpu().numpy()
            true = data.y[data.test_mask].cpu().numpy()
            auc = roc_auc_score(true, probs)
            total_aucs.append(auc)
            num_iterations += 1
            print(f"Iteration {num_iterations}/50 | AUC = {auc:.4f}")

# 최종 결과 출력
mean_auc = np.mean(total_aucs)
print(f"\n Final classification performance reported as mean AUC over 50 iterations: {mean_auc:.4f}")
# Out:
#  Repeat 1/10
#
# Fold 1/5
# - Test indices (sample): [10, 19, 21, 37, 43] ... 총 102개
# - Train+Val indices (sample): [0, 1, 2, 3, 4] ... 총 404개
#   - Train size: 323 (63.83%)
#   - Val size:   81 (16.01%)
#   - Test size:  102 (20.16%)
# Iteration 1/50 | AUC = 0.5000
#
# Fold 2/5
# - Test indices (sample): [2, 4, 5, 8, 14] ... 총 101개
# - Train+Val indices (sample): [0, 1, 3, 6, 7] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 2/50 | AUC = 0.4927
#
# Fold 3/5
# - Test indices (sample): [7, 20, 24, 29, 35] ... 총 101개
# - Train+Val indices (sample): [0, 1, 2, 3, 4] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 3/50 | AUC = 0.5000
#
# Fold 4/5
# - Test indices (sample): [1, 3, 9, 11, 18] ... 총 101개
# - Train+Val indices (sample): [0, 2, 4, 5, 6] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 4/50 | AUC = 0.5000
#
# Fold 5/5
# - Test indices (sample): [0, 6, 12, 13, 15] ... 총 101개
# - Train+Val indices (sample): [1, 2, 3, 4, 5] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 5/50 | AUC = 0.5000
#
#  Repeat 2/10
#
# Fold 1/5
# - Test indices (sample): [13, 22, 30, 35, 36] ... 총 102개
# - Train+Val indices (sample): [0, 1, 2, 3, 4] ... 총 404개
#   - Train size: 323 (63.83%)
#   - Val size:   81 (16.01%)
#   - Test size:  102 (20.16%)
# Iteration 6/50 | AUC = 0.5000
#
# Fold 2/5
# - Test indices (sample): [0, 7, 10, 24, 25] ... 총 101개
# - Train+Val indices (sample): [1, 2, 3, 4, 5] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 7/50 | AUC = 0.5000
#
# Fold 3/5
# - Test indices (sample): [4, 5, 16, 23, 38] ... 총 101개
# - Train+Val indices (sample): [0, 1, 2, 3, 6] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 8/50 | AUC = 0.5000
#
# Fold 4/5
# - Test indices (sample): [3, 6, 9, 12, 15] ... 총 101개
# - Train+Val indices (sample): [0, 1, 2, 4, 5] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 9/50 | AUC = 0.5000
#
# Fold 5/5
# - Test indices (sample): [1, 2, 8, 11, 14] ... 총 101개
# - Train+Val indices (sample): [0, 3, 4, 5, 6] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 10/50 | AUC = 0.5000
#
#  Repeat 3/10
#
# Fold 1/5
# - Test indices (sample): [11, 12, 14, 19, 20] ... 총 102개
# - Train+Val indices (sample): [0, 1, 2, 3, 4] ... 총 404개
#   - Train size: 323 (63.83%)
#   - Val size:   81 (16.01%)
#   - Test size:  102 (20.16%)
# Iteration 11/50 | AUC = 0.4900
#
# Fold 2/5
# - Test indices (sample): [1, 5, 7, 13, 15] ... 총 101개
# - Train+Val indices (sample): [0, 2, 3, 4, 6] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 12/50 | AUC = 0.5000
#
# Fold 3/5
# - Test indices (sample): [4, 23, 33, 34, 38] ... 총 101개
# - Train+Val indices (sample): [0, 1, 2, 3, 5] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 13/50 | AUC = 0.5000
#
# Fold 4/5
# - Test indices (sample): [0, 2, 6, 9, 16] ... 총 101개
# - Train+Val indices (sample): [1, 3, 4, 5, 7] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 14/50 | AUC = 0.5000
#
# Fold 5/5
# - Test indices (sample): [3, 8, 10, 17, 24] ... 총 101개
# - Train+Val indices (sample): [0, 1, 2, 4, 5] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 15/50 | AUC = 0.5000
#
#  Repeat 4/10
#
# Fold 1/5
# - Test indices (sample): [0, 6, 8, 9, 10] ... 총 102개
# - Train+Val indices (sample): [1, 2, 3, 4, 5] ... 총 404개
#   - Train size: 323 (63.83%)
#   - Val size:   81 (16.01%)
#   - Test size:  102 (20.16%)
# Iteration 16/50 | AUC = 0.5000
#
# Fold 2/5
# - Test indices (sample): [1, 3, 7, 14, 16] ... 총 101개
# - Train+Val indices (sample): [0, 2, 4, 5, 6] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 17/50 | AUC = 0.5000
#
# Fold 3/5
# - Test indices (sample): [2, 13, 17, 18, 28] ... 총 101개
# - Train+Val indices (sample): [0, 1, 3, 4, 5] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 18/50 | AUC = 0.5000
#
# Fold 4/5
# - Test indices (sample): [4, 5, 20, 27, 29] ... 총 101개
# - Train+Val indices (sample): [0, 1, 2, 3, 6] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 19/50 | AUC = 0.5000
#
# Fold 5/5
# - Test indices (sample): [15, 19, 24, 25, 26] ... 총 101개
# - Train+Val indices (sample): [0, 1, 2, 3, 4] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 20/50 | AUC = 0.4898
#
#  Repeat 5/10
#
# Fold 1/5
# - Test indices (sample): [0, 2, 3, 4, 13] ... 총 102개
# - Train+Val indices (sample): [1, 5, 6, 7, 8] ... 총 404개
#   - Train size: 323 (63.83%)
#   - Val size:   81 (16.01%)
#   - Test size:  102 (20.16%)
# Iteration 21/50 | AUC = 0.5000
#
# Fold 2/5
# - Test indices (sample): [5, 7, 11, 16, 17] ... 총 101개
# - Train+Val indices (sample): [0, 1, 2, 3, 4] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 22/50 | AUC = 0.5000
#
# Fold 3/5
# - Test indices (sample): [10, 14, 29, 43, 46] ... 총 101개
# - Train+Val indices (sample): [0, 1, 2, 3, 4] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 23/50 | AUC = 0.5000
#
# Fold 4/5
# - Test indices (sample): [8, 19, 22, 24, 31] ... 총 101개
# - Train+Val indices (sample): [0, 1, 2, 3, 4] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 24/50 | AUC = 0.5000
#
# Fold 5/5
# - Test indices (sample): [1, 6, 9, 12, 15] ... 총 101개
# - Train+Val indices (sample): [0, 2, 3, 4, 5] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 25/50 | AUC = 0.5000
#
#  Repeat 6/10
#
# Fold 1/5
# - Test indices (sample): [14, 27, 35, 36, 37] ... 총 102개
# - Train+Val indices (sample): [0, 1, 2, 3, 4] ... 총 404개
#   - Train size: 323 (63.83%)
#   - Val size:   81 (16.01%)
#   - Test size:  102 (20.16%)
# Iteration 26/50 | AUC = 0.5000
#
# Fold 2/5
# - Test indices (sample): [0, 3, 6, 8, 12] ... 총 101개
# - Train+Val indices (sample): [1, 2, 4, 5, 7] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 27/50 | AUC = 0.5000
#
# Fold 3/5
# - Test indices (sample): [11, 15, 19, 22, 28] ... 총 101개
# - Train+Val indices (sample): [0, 1, 2, 3, 4] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 28/50 | AUC = 0.5000
#
# Fold 4/5
# - Test indices (sample): [1, 2, 7, 9, 10] ... 총 101개
# - Train+Val indices (sample): [0, 3, 4, 5, 6] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 29/50 | AUC = 0.5000
#
# Fold 5/5
# - Test indices (sample): [4, 5, 17, 20, 21] ... 총 101개
# - Train+Val indices (sample): [0, 1, 2, 3, 6] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 30/50 | AUC = 0.5000
#
#  Repeat 7/10
#
# Fold 1/5
# - Test indices (sample): [2, 4, 7, 9, 12] ... 총 102개
# - Train+Val indices (sample): [0, 1, 3, 5, 6] ... 총 404개
#   - Train size: 323 (63.83%)
#   - Val size:   81 (16.01%)
#   - Test size:  102 (20.16%)
# Iteration 31/50 | AUC = 0.5000
#
# Fold 2/5
# - Test indices (sample): [5, 8, 10, 11, 14] ... 총 101개
# - Train+Val indices (sample): [0, 1, 2, 3, 4] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 32/50 | AUC = 0.5000
#
# Fold 3/5
# - Test indices (sample): [20, 22, 24, 31, 35] ... 총 101개
# - Train+Val indices (sample): [0, 1, 2, 3, 4] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 33/50 | AUC = 0.5000
#
# Fold 4/5
# - Test indices (sample): [0, 1, 21, 28, 29] ... 총 101개
# - Train+Val indices (sample): [2, 3, 4, 5, 6] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 34/50 | AUC = 0.5000
#
# Fold 5/5
# - Test indices (sample): [3, 6, 13, 17, 19] ... 총 101개
# - Train+Val indices (sample): [0, 1, 2, 4, 5] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 35/50 | AUC = 0.5000
#
#  Repeat 8/10
#
# Fold 1/5
# - Test indices (sample): [7, 17, 20, 22, 28] ... 총 102개
# - Train+Val indices (sample): [0, 1, 2, 3, 4] ... 총 404개
#   - Train size: 323 (63.83%)
#   - Val size:   81 (16.01%)
#   - Test size:  102 (20.16%)
# Iteration 36/50 | AUC = 0.5000
#
# Fold 2/5
# - Test indices (sample): [2, 3, 10, 18, 23] ... 총 101개
# - Train+Val indices (sample): [0, 1, 4, 5, 6] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 37/50 | AUC = 0.5000
#
# Fold 3/5
# - Test indices (sample): [0, 8, 12, 13, 16] ... 총 101개
# - Train+Val indices (sample): [1, 2, 3, 4, 5] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 38/50 | AUC = 0.5000
#
# Fold 4/5
# - Test indices (sample): [4, 15, 29, 33, 52] ... 총 101개
# - Train+Val indices (sample): [0, 1, 2, 3, 5] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 39/50 | AUC = 0.5000
#
# Fold 5/5
# - Test indices (sample): [1, 5, 6, 9, 11] ... 총 101개
# - Train+Val indices (sample): [0, 2, 3, 4, 7] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 40/50 | AUC = 0.5000
#
#  Repeat 9/10
#
# Fold 1/5
# - Test indices (sample): [5, 7, 20, 25, 28] ... 총 102개
# - Train+Val indices (sample): [0, 1, 2, 3, 4] ... 총 404개
#   - Train size: 323 (63.83%)
#   - Val size:   81 (16.01%)
#   - Test size:  102 (20.16%)
# Iteration 41/50 | AUC = 0.5000
#
# Fold 2/5
# - Test indices (sample): [8, 12, 18, 34, 36] ... 총 101개
# - Train+Val indices (sample): [0, 1, 2, 3, 4] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 42/50 | AUC = 0.5000
#
# Fold 3/5
# - Test indices (sample): [19, 21, 23, 29, 31] ... 총 101개
# - Train+Val indices (sample): [0, 1, 2, 3, 4] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 43/50 | AUC = 0.5000
#
# Fold 4/5
# - Test indices (sample): [0, 2, 3, 10, 11] ... 총 101개
# - Train+Val indices (sample): [1, 4, 5, 6, 7] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 44/50 | AUC = 0.5000
#
# Fold 5/5
# - Test indices (sample): [1, 4, 6, 9, 13] ... 총 101개
# - Train+Val indices (sample): [0, 2, 3, 5, 7] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 45/50 | AUC = 0.4115
#
#  Repeat 10/10
#
# Fold 1/5
# - Test indices (sample): [9, 12, 16, 19, 20] ... 총 102개
# - Train+Val indices (sample): [0, 1, 2, 3, 4] ... 총 404개
#   - Train size: 323 (63.83%)
#   - Val size:   81 (16.01%)
#   - Test size:  102 (20.16%)
# Iteration 46/50 | AUC = 0.5000
#
# Fold 2/5
# - Test indices (sample): [3, 10, 11, 15, 17] ... 총 101개
# - Train+Val indices (sample): [0, 1, 2, 4, 5] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 47/50 | AUC = 0.5000
#
# Fold 3/5
# - Test indices (sample): [1, 7, 8, 14, 28] ... 총 101개
# - Train+Val indices (sample): [0, 2, 3, 4, 5] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 48/50 | AUC = 0.5000
#
# Fold 4/5
# - Test indices (sample): [0, 4, 5, 6, 21] ... 총 101개
# - Train+Val indices (sample): [1, 2, 3, 7, 8] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 49/50 | AUC = 0.5000
#
# Fold 5/5
# - Test indices (sample): [2, 13, 25, 27, 31] ... 총 101개
# - Train+Val indices (sample): [0, 1, 3, 4, 5] ... 총 405개
#   - Train size: 324 (64.03%)
#   - Val size:   81 (16.01%)
#   - Test size:  101 (19.96%)
# Iteration 50/50 | AUC = 0.5000
#
#  Final classification performance reported as mean AUC over 50 iterations: 0.4977
